# %% [markdown]
# ### Importing Packages

# %%
import nltk
import re
import numpy as np
import pandas as pd
from pprint import pprint
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import spacy
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ### Appending of stopwords
# Additional words which does not add value to the analysis has been added into the list of stop words too

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.append("product")
stop_words.append('products')
stop_words.append('items')
stop_words.append("item")
stop_words.append("garnier")
stop_words.append("skin")
stop_words.append("micellar")
stop_words.append("hair")
stop_words.append("makeup")
stop_words.append("love")
stop_words.append("water")
stop_words.append("face")
stop_words.append("use")
stop_words.append("thank")
stop_words.append("thanks")
stop_words.append("order")
stop_words.append("eye")
stop_words.append("remover")
stop_words.append("mask")
stop_words.append("foundation")
stop_words.append("purchase")
stop_words.append('lip')
stop_words.append('lipstick')
stop_words.append('buy')
stop_words.append('use')
stop_words.append('delivery')
stop_words.append('mascara')
# stop_words.append('seller')

# %% [markdown]
# ### Functions for dfferent preprocessing steps

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]


def lemmatization(texts, allowed_postags=['ADJ', 'NOUN','VERB','ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
data_file = "Data/all_data_clean_nonsplit.csv"
df = pd.read_csv(data_file)
# df = df.rename(columns = {'Review_splitted': 'Review_clean'})

#removing of some reviews which does not have any meaning
df = df[df["Review_clean"] != "no comments review is an image" ]
df = df[df["Review_clean"] != "no review receive" ]
df = df[df["Review_clean"] != "your review has been hidden due to inappropriate content note hope may remove the coins awarded for this review" ]
print(len(df))
df
# Out:
# 4048
#       Unnamed: 0 Platform          Brand  \
# 0              0   Shopee  L'Oreal Paris
# 1              1   Shopee  L'Oreal Paris
# 2              2   Shopee  L'Oreal Paris
# 3              3   Shopee  L'Oreal Paris
# 4              4   Shopee  L'Oreal Paris
# 5              5   Shopee  L'Oreal Paris
# 6              6   Shopee  L'Oreal Paris
# 7              7   Shopee  L'Oreal Paris
# 8              8   Shopee  L'Oreal Paris
# 9              9   Shopee  L'Oreal Paris
# 10            10   Shopee  L'Oreal Paris
# 11            11   Shopee  L'Oreal Paris
# 12            12   Shopee  L'Oreal Paris
# 13            13   Shopee  L'Oreal Paris
# 14            14   Shopee  L'Oreal Paris
# 15            15   Shopee  L'Oreal Paris
# 16            16   Shopee  L'Oreal Paris
# 17            17   Shopee  L'Oreal Paris
# 18            18   Shopee  L'Oreal Paris
# 19            19   Shopee  L'Oreal Paris
# 20            20   Shopee  L'Oreal Paris
# 21            21   Shopee  L'Oreal Paris
# 22            22   Shopee  L'Oreal Paris
# 23            23   Shopee  L'Oreal Paris
# 24            24   Shopee  L'Oreal Paris
# 25            25   Shopee  L'Oreal Paris
# 26            26   Shopee  L'Oreal Paris
# 27            27   Shopee  L'Oreal Paris
# 28            28   Shopee  L'Oreal Paris
# 29            29   Shopee  L'Oreal Paris
# ...          ...      ...            ...
# 4020        4020   Lazada     Maybelline
# 4021        4021   Lazada     Maybelline
# 4022        4022   Lazada     Maybelline
# 4023        4023   Lazada     Maybelline
# 4024        4024   Lazada     Maybelline
# 4025        4025   Lazada     Maybelline
# 4026        4026   Lazada     Maybelline
# 4027        4027   Lazada     Maybelline
# 4028        4028   Lazada     Maybelline
# 4029        4029   Lazada     Maybelline
# 4030        4030   Lazada     Maybelline
# 4031        4031   Lazada     Maybelline
# 4032        4032   Lazada     Maybelline
# 4033        4033   Lazada     Maybelline
# 4034        4034   Lazada     Maybelline
# 4035        4035   Lazada     Maybelline
# 4036        4036   Lazada     Maybelline
# 4037        4037   Lazada     Maybelline
# 4038        4038   Lazada     Maybelline
# 4039        4039   Lazada     Maybelline
# 4040        4040   Lazada     Maybelline
# 4041        4041   Lazada     Maybelline
# 4042        4042   Lazada     Maybelline
# 4043        4043   Lazada     Maybelline
# 4044        4044   Lazada     Maybelline
# 4045        4045   Lazada     Maybelline
# 4046        4046   Lazada     Maybelline
# 4047        4047   Lazada     Maybelline
# 4048        4048   Lazada     Maybelline
# 4049        4049   Lazada     Maybelline
#
#                                    Category  \
# 0                         Serum & Treatment
# 1                         Serum & Treatment
# 2                         Serum & Treatment
# 3                         Serum & Treatment
# 4                         Serum & Treatment
# 5                         Serum & Treatment
# 6                         Serum & Treatment
# 7                         Serum & Treatment
# 8                         Serum & Treatment
# 9                         Serum & Treatment
# 10                        Serum & Treatment
# 11                        Serum & Treatment
# 12                        Serum & Treatment
# 13                        Serum & Treatment
# 14                        Serum & Treatment
# 15                        Serum & Treatment
# 16                        Serum & Treatment
# 17                        Serum & Treatment
# 18                        Serum & Treatment
# 19                        Serum & Treatment
# 20                        Serum & Treatment
# 21                        Serum & Treatment
# 22                        Serum & Treatment
# 23                        Serum & Treatment
# 24                        Serum & Treatment
# 25                        Serum & Treatment
# 26                        Serum & Treatment
# 27                        Serum & Treatment
# 28                        Serum & Treatment
# 29                        Serum & Treatment
# ...                                     ...
# 4020                  Shimmers Highlighters
# 4021                  Shimmers Highlighters
# 4022                  Shimmers Highlighters
# 4023                        Compacts Powder
# 4024                        Compacts Powder
# 4025                        Compacts Powder
# 4026                        Compacts Powder
# 4027                        Compacts Powder
# 4028                        Compacts Powder
# 4029                        Compacts Powder
# 4030                        Compacts Powder
# 4031                        Compacts Powder
# 4032                        Compacts Powder
# 4033                        Compacts Powder
# 4034                        Compacts Powder
# 4035                        Compacts Powder
# 4036                        Compacts Powder
# 4037                   Makeup Base & Primer
# 4038                   Makeup Base & Primer
# 4039                   Makeup Base & Primer
# 4040  Multi-Function Makeup Palettes & Sets
# 4041  Multi-Function Makeup Palettes & Sets
# 4042  Multi-Function Makeup Palettes & Sets
# 4043                        Makeup Removers
# 4044                        Makeup Removers
# 4045                        Makeup Removers
# 4046                        Makeup Removers
# 4047                          Face Cleanser
# 4048                          Face Cleanser
# 4049                          Face Cleanser
#
#                                           Product Name   Price  \
# 0     L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 1     L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 2     L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 3     L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 4     L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 5     L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 6     L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 7     L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 8     L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 9     L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 10    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 11    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 12    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 13    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 14    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 15    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 16    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 17    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 18    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 19    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 20    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 21    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 22    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 23    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 24    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 25    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 26    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 27    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 28    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# 29    L'Oreal Paris Revitalift Crystal Micro-Essence...   25.9
# ...                                                 ...    ...
# 4020  Maybelline Facestudio Master Chrome Molten Gol...   19.9
# 4021  Maybelline Facestudio Master Chrome Molten Gol...   19.9
# 4022  Maybelline Facestudio Master Chrome Molten Gol...   19.9
# 4023  Maybelline Fit Me Matte+Poreless Powder Founda...   12.7
# 4024  Maybelline Fit Me Matte+Poreless Powder Founda...   12.7
# 4025  Maybelline Fit Me Matte+Poreless Powder Founda...   12.7
# 4026  Maybelline Fit Me Matte+Poreless Powder Founda...   12.7
# 4027  Maybelline Fit Me Matte+Poreless Powder Founda...   12.7
# 4028  Maybelline Fit Me Matte+Poreless Powder Founda...   12.7
# 4029  Maybelline Fit Me Matte+Poreless Powder Founda...   12.7
# 4030  Maybelline Fit Me Matte+Poreless Powder Founda...   12.7
# 4031  Maybelline Fit Me Matte+Poreless Powder Founda...   12.7
# 4032  Maybelline Fit Me Matte+Poreless Powder Founda...   12.7
# 4033  Maybelline Fit Me Matte+Poreless Powder Founda...   12.7
# 4034  Maybelline Fit Me Matte+Poreless Powder Founda...   12.7
# 
# 4048  Scent:Not Specified, Volume (ml):40      5.0  2020-03-13 00:00:00
# 4049  Scent:Not Specified, Volume (ml):40      5.0  2020-03-13 00:00:00
#
#      Response
# 0          no
# 1          no
# 2          no
# 3          no
# 4          no
# 5          no
# 6          no
# 7          no
# 8          no
# 9          no
# 10         no
# 11         no
# 12         no
# 13         no
# 14         no
# 15         no
# 16         no
# 17         no
# 18         no
# 19         no
# 20         no
# 21         no
# 22         no
# 23         no
# 24         no
# 25         no
# 26         no
# 27         no
# 28         no
# 29         no
# ...       ...
# 4020      yes
# 4021       no
# 4022       no
# 4023      yes
# 4024      yes
# 4025      yes
# 4026      yes
# 4027      yes
# 4028       no
# 4029      yes
# 4030      yes
# 4031      yes
# 4032      yes
# 4033      yes
# 4034       no
# 4035       no
# 4036       no
# 4037      yes
# 4038      yes
# 4039       no
# 4040      yes
# 4041      yes
# 4042       no
# 4043      yes
# 4044       no
# 4045       no
# 4046       no
# 4047      yes
# 4048      yes
# 4049       no
#
# [4048 rows x 13 columns]

# %%
data = df.Review_clean.values.tolist()
data_words = list(sent_to_words(data))

#Removing of stopwords
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams      
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=50) # higher threshold fewer phrases.
bigram_mod = gensim.models.phrases.Phraser(bigram)
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['ADJ', 'NOUN'])
# Out:
# 4048
# C:\Users\User\Anaconda3\lib\site-packages\gensim\models\phrases.py:494: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %% [markdown]
# ### LDA Model

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# ### Getting the optimal number of topics
# Applying the LDA model to different number to get the optimal number of topics based on the coherence score

# %%
import datetime
print(datetime.datetime.now())

from gensim.models import CoherenceModel

model_list = []
coherence_values = []
model_topics = []

for num_topics in range(2, 10):
    lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=num_topics, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=10000,
                                           passes=100,
                                           alpha=1, 
                                            eta = 0.01,
                                            per_word_topics = True)
    
    coherencemodel = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
    model_topics.append(num_topics)
    model_list.append(lda_model)
    coherence_values.append(coherencemodel.get_coherence())
    print("#Topics: " + str(num_topics) + " Score: " + str(coherencemodel.get_coherence()) + " " + str(lda_model.log_perplexity(corpus)))

print(datetime.datetime.now())
# Out:
# 2020-03-25 14:42:27.930384
# C:\Users\User\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# #Topics: 2 Score: 0.3138034780466943 -6.769098639318906
# #Topics: 3 Score: 0.32927041319875844 -6.772994414137825
# #Topics: 4 Score: 0.3388973557320696 -6.758885783175122
# #Topics: 5 Score: 0.3535323897981998 -6.761948034705006
# #Topics: 6 Score: 0.33946694906549163 -6.766066597372105
# #Topics: 7 Score: 0.36322652340652156 -6.764956105786271
# #Topics: 8 Score: 0.3734852797233354 -6.775712805720756
# #Topics: 9 Score: 0.3607811489463028 -6.773972449067208
# 2020-03-25 15:32:10.046476

# %%
import matplotlib.pyplot as plt

limit=10; start=2; step=1;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.savefig('topic_coherence_combine.png')
plt.show()

# %% [markdown]
# ### Results obtain by LDA model

# %%
lda_model_5topic = model_list[2]
pprint(lda_model_5topic.print_topics(num_words = 15))

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model_5topic, corpus, id2word)
vis
# pyLDAvis.save_html(vis, 'lda_7topic_combine.html')
# Out:
# [(0,
#   '0.055*"dry" + 0.050*"week" + 0.049*"oil" + 0.041*"smooth" + 0.028*"smell" + '
#   '0.019*"application" + 0.017*"last" + 0.017*"soft" + 0.017*"powder" + '
#   '0.014*"essence" + 0.012*"hydrated" + 0.012*"thick" + 0.012*"way" + '
#   '0.012*"frizzy" + 0.012*"fresh"'),
#  (1,
#   '0.057*"easy" + 0.033*"work" + 0.024*"sensitive" + 0.023*"much" + '
#   '0.021*"hour" + 0.018*"suitable" + 0.017*"touch" + 0.014*"apply" + '
#   '0.014*"make" + 0.013*"new" + 0.012*"clean" + 0.012*"hydration" + '
#   '0.011*"oily" + 0.011*"scent" + 0.011*"cover"'),
#  (2,
#   '0.072*"price" + 0.062*"great" + 0.051*"cheap" + 0.045*"sale" + 0.042*"hope" '
#   '+ 0.029*"condition" + 0.028*"quality" + 0.028*"brand" + 0.025*"retail" + '
#   '0.022*"store" + 0.022*"perfect" + 0.019*"year" + 0.016*"satisfied" + '
#   '0.015*"discount" + 0.013*"different"'),
#  (3,
#   '0.113*"fast" + 0.101*"seller" + 0.086*"free" + 0.084*"good_condition" + '
#   '0.059*"worth" + 0.041*"deal" + 0.028*"value" + 0.025*"bottle" + '
#   '0.023*"package" + 0.021*"shipping" + 0.020*"money" + 0.017*"happy" + '
#   '0.015*"flash_sale" + 0.015*"date" + 0.014*"promotion"'),
#  (4,
#   '0.360*"good" + 0.046*"color" + 0.031*"packaging" + 0.024*"bit" + '
#   '0.024*"service" + 0.021*"mask" + 0.018*"lip" + 0.013*"box" + 0.013*"review" '
#   '+ 0.013*"authentic" + 0.013*"bag" + 0.013*"envelope" + 0.011*"promo" + '
#   '0.010*"slow" + 0.009*"suit"'),
#  (5,
#   '0.150*"day" + 0.086*"time" + 0.026*"lot" + 0.023*"long" + 0.023*"little" + '
#   '0.019*"tone" + 0.017*"friend" + 0.016*"texture" + 0.013*"morning" + '
#   '0.013*"thing" + 0.013*"try" + 0.012*"month" + 0.012*"remove" + '
#   '0.012*"first" + 0.011*"bright"'),
#  (6,
#   '0.090*"colour" + 0.079*"nice" + 0.031*"shade" + 0.031*"light" + '
#   '0.029*"coverage" + 0.026*"quick" + 0.021*"bottle" + 0.021*"concealer" + '
#   '0.020*"small" + 0.020*"bad" + 0.019*"dark" + 0.017*"big" + 0.016*"picture" '
#   '+ 0.014*"natural" + 0.014*"today"')]
# C:\Users\User\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))

# %% [markdown]
# ### Get the dominant topic for each of the review
#
# Look at the reviews and its respective dominant topic given by the LDA model to understand how the lda model classifiy the reviews and to better understand the topics and keyword generated by the lda model. After understanding this, we can better give a name/label to the topics generated

# %%
bow = [id2word.doc2bow(line) for line in texts] # get the bow-format lines with the set dictionary

review = []
topic = []
percentage = []
for line,bag in zip(data,bow):
    doc_topics = [(topic, prob) for topic,prob in lda_model_5topic.get_document_topics(bag)]
    doc_topics = sorted(doc_topics, key=lambda x: (x[1]), reverse=True)
#     print(doc_topics)
    dominant_topic = doc_topics[0][0]
    percen = doc_topics[0][1]
    review.append(line)
    topic.append(dominant_topic)
    percentage.append(percen)


keyword = []
for i in range(len(topic)):
    wp = lda_model_5topic.show_topic(topic[i])
    topic_keywords = ", ".join([word for word, prop in wp])
    keyword.append(topic_keywords)
    
df_topic = {'review': review,'keyword': keyword, "topic": topic, "percentage": percentage}
new_df = pd.DataFrame.from_dict(df_topic)


new_df.to_csv('4topic_combine.csv')
new_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-533f609ad05b> in <module>
# ----> 1 bow = [id2word.doc2bow(line) for line in texts] # get the bow-format lines with the set dictionary
#       2
#       3 review = []
#       4 topic = []
#       5 percentage = []
#
# NameError: name 'texts' is not defined
